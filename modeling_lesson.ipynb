# %% [markdown]
# # Forecasting
#
#
# In this lesson, we will practice forecasting using the following methods:
#
# - Last observed value
# - Simple average
# - Moving average
# - Holt's Linear Trend
# - Holt's Seasonal Trend
# - Previous cycle
#
# ______________________________
#
#
# We will walk through steps from previous lessons to get the data ready to model
#
# - Acquire data: acquire.wrangle_store_data()
# - Prepare data: prepare.prep_store_data()
#
# Then we will forecast and evaluate using each method.

# %%
# for presentation purposes
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# visualize 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# wrangle
import acquire
import prepare

# working with dates
from datetime import datetime

# to evaluated performance using rmse
from sklearn.metrics import mean_squared_error
from math import sqrt 

# for tsa 
import statsmodels.api as sm

# holt's linear trend model. 
from statsmodels.tsa.api import Holt, ExponentialSmoothing

# Plt defaults
# plt.style.use('seaborn-whitegrid')
plt.rc('figure', figsize=(14, 8))
plt.rc('font', size=16)

# %% [markdown]
# ## Wrangle

# %%
df = pd.read_csv('tsa_item_demand.csv')
df = prepare.prepare_store_data(df)
df.head()
# Out:
#             store_id  item_id   item_upc14   item_upc12          item_brand  \
# sale_date
# 2013-01-01         1        1  35200264013  35200264013            Riceland
# 2013-01-01         3       17  88313590791  88313590791               Ducal
# 2013-01-01        10        7  70177154004  70177154004  Twinings Of London
# 2013-01-01         3       18  21200725340  21200725340              Scotch
# 2013-01-01         3       19  41520035646  41520035646             Careone
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01                            Ducal Refried Red Beans        1.16
# 2013-01-01  Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 2013-01-01    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 2013-01-01                     Careone Family Comb Set - 8 Ct        0.74
#
#             sale_id  sale_amount            store_address  store_zipcode  \
# sale_date
# 2013-01-01        1           13   12125 Alamo Ranch Pkwy          78253
# 2013-01-01   295813           26  2118 Fredericksburg Rdj          78201
# 2013-01-01   125995           32     8503 NW Military Hwy          78231
# 2013-01-01   314073           45  2118 Fredericksburg Rdj          78201
# 2013-01-01   332333           34  2118 Fredericksburg Rdj          78201
#
#              store_city store_state  sales_total
# sale_date
# 2013-01-01  San Antonio          TX        10.92
# 2013-01-01  San Antonio          TX        30.16
# 2013-01-01  San Antonio          TX       308.48
# 2013-01-01  San Antonio          TX       197.55
# 2013-01-01  San Antonio          TX        25.16

# %% [markdown]
# We will resample to daily, but essentially what we are doing is grouping by the day and aggregating using sum. The original granularity is daily, but there are multiple records of the same days across multiple stores.

# %%
df_resampled = df.resample('d')[['quantity','sales_total']].sum()
df_resampled.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24900\2098940125.py in <module>
# ----> 1 df_resampled = df.resample('d')[['quantity','sales_total']].sum()
#       2 df_resampled.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     238             if len(self.obj.columns.intersection(key)) != len(set(key)):
#     239                 bad_keys = list(set(key).difference(self.obj.columns))
# --> 240                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     241             return self._gotitem(list(key), ndim=2)
#     242
#
# KeyError: "Columns not found: 'quantity'"

# %% [markdown]
# ## Split
#
# 1. We will use the training proportion method to split.
# 2. Identify the total length of the dataframe and multiply by `train_prop` to get the number of rows that equates to the first x% of the dataframe, which equates to the first x% of the time covered in the data.   (`x = train_prop * 100`)
# 3. Select row indices from 0 up to the index representing x-percentile for train, and from the index representing x-percentile through the end of the dataframe for test. In both of these, we will reset the index in order to return dataframes sorted by datetime.
# 4. Return train, validate, and test dataframes.

# %%
df_resampled.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24900\1844852727.py in <module>
# ----> 1 df_resampled.shape
#
# NameError: name 'df_resampled' is not defined

# %%
# set train size to be 50% of total 
train_size = int(round(df_resampled.shape[0] * 0.5))
train_size
# Out:
# 913

# %%
# set validate size to be 30% of total 
validate_size = int(round(df_resampled.shape[0] * 0.3))
validate_size
# Out:
# 548

# %%
# set test size to be number of rows remaining. 
test_size = int(round(df_resampled.shape[0] * 0.2))
test_size
# Out:
# 365

# %%
len(df_resampled) == train_size + validate_size + test_size
# Out:
# True

# %%
# validate will go from 913 to 913+548
validate_end_index = train_size + validate_size
validate_end_index
# Out:
# 1461

# %% [markdown]
# Use those values to split our dataframe

# %%
# train will go from 0 to 912
train = df_resampled[:train_size]

# %%
# validate will go from 912 to 1458
validate = df_resampled[train_size:validate_end_index]

# %%
train.tail()
# Out:
#             quantity  sales_total
# sale_date
# 2015-06-28     37410    201002.82
# 2015-06-29     25074    134932.08
# 2015-06-30     29345    158904.06
# 2015-07-01     30703    164573.20
# 2015-07-02     33134    178036.64

# %%
validate.head()
# Out:
#             quantity  sales_total
# sale_date
# 2015-07-03     35498    190981.55
# 2015-07-04     37776    203696.39
# 2015-07-05     39740    214040.37
# 2015-07-06     26519    142584.15
# 2015-07-07     30916    167146.03

# %%
validate.tail()
# Out:
#             quantity  sales_total
# sale_date
# 2016-12-27     19341    103657.89
# 2016-12-28     19560    105313.94
# 2016-12-29     21111    113221.85
# 2016-12-30     22296    120033.64
# 2016-12-31     23792    128009.31

# %%
# test will include 1459 to the end
test = df_resampled[validate_end_index:]

# %%
test.head()
# Out:
#             quantity  sales_total
# sale_date
# 2017-01-01     23709    127262.71
# 2017-01-02     15772     85329.98
# 2017-01-03     18650    100389.65
# 2017-01-04     18510     99454.59
# 2017-01-05     19895    107613.80

# %%
train.shape[0], validate.shape[0], test.shape[0]
# Out:
# (913, 548, 365)

# %% [markdown]
# **Verify Splits**
#
# Does the length of each df equate to the length of the original df?

# %%
# is len of train + validate + test == lenght of entire dataframe. 
len(train) + len(validate) + len(test) == len(df_resampled)
# Out:
# True

# %% [markdown]
# Does the first row of original df equate to the first row of train?

# %%
print(df_resampled.head(1) == train.head(1))
# Out:
#             quantity  sales_total
# sale_date
# 2013-01-01      True         True

# %% [markdown]
# Is the last row of train the day before the first row of validate? And the same for validate to test?

# %%
pd.concat([train.tail(1), validate.head(1)])
# Out:
#             quantity  sales_total
# sale_date
# 2015-07-02     33134    178036.64
# 2015-07-03     35498    190981.55

# %%
pd.concat([validate.tail(1), test.head(1)])
# Out:
#             quantity  sales_total
# sale_date
# 2016-12-31     23792    128009.31
# 2017-01-01     23709    127262.71

# %% [markdown]
# Is the last row of test the same as the last row of our original dataframe?

# %%
pd.concat([test.tail(1), df_resampled.tail(1)])
# Out:
#             quantity  sales_total
# sale_date
# 2017-12-31     26420    140905.74
# 2017-12-31     26420    140905.74

# %% [markdown]
# Let's plot our data first, viewing where the data is split into train and test.

# %%
train.columns
# Out:
# Index(['quantity', 'sales_total'], dtype='object')

# %%
for col in train.columns:
    plt.plot(train[col])
    plt.plot(validate[col])
    plt.plot(test[col])
    plt.ylabel(col)
    plt.title(col)
    plt.show()

# %% [markdown]
# Before we try out different methods for forecasting sales and number of items sold, let's create a couple of functions that will be helpful in evaluating each of the methods that follow.
#
# `evaluate()` will compute the Mean Squared Error and the Root Mean Squared Error to evaluate.

# %%
def evaluate(target_var):
    '''
    This function will take the actual values of the target_var from validate, 
    and the predicted values stored in yhat_df, 
    and compute the rmse, rounding to 0 decimal places. 
    it will return the rmse. 
    '''
    rmse = round(sqrt(mean_squared_error(validate[target_var], yhat_df[target_var])), 0)
    return rmse

# %% [markdown]
# `plot_and_eval()` will use the evaluate function and also plot train and test values with the predicted values in order to compare performance.

# %%
def plot_and_eval(target_var):
    '''
    This function takes in the target var name (string), and returns a plot
    of the values of train for that variable, validate, and the predicted values from yhat_df. 
    it will als lable the rmse. 
    '''
    plt.figure(figsize = (12,4))
    plt.plot(train[target_var], label='Train', linewidth=1)
    plt.plot(validate[target_var], label='Validate', linewidth=1)
    plt.plot(yhat_df[target_var])
    plt.title(target_var)
    rmse = evaluate(target_var)
    print(target_var, '-- RMSE: {:.0f}'.format(rmse))
    plt.show()

# %% [markdown]
# Write `append_eval_df(model_type)` to append evaluation metrics for each model type, target variable, and metric type, along with the metric value into our `eval_df` data frame object. Which we will create an empty `eval_df` dataframe object to start.

# %%
# create an empty dataframe
eval_df = pd.DataFrame(columns=['model_type', 'target_var', 'rmse'])
eval_df
# Out:
# Empty DataFrame
# Columns: [model_type, target_var, rmse]
# Index: []

# %%
# function to store the rmse so that we can compare
def append_eval_df(model_type, target_var):
    '''
    this function takes in as arguments the type of model run, and the name of the target variable. 
    It returns the eval_df with the rmse appended to it for that model and target_var. 
    '''
    rmse = evaluate(target_var)
    d = {'model_type': [model_type], 'target_var': [target_var],
        'rmse': [rmse]}
    d = pd.DataFrame(d)
    return eval_df.append(d, ignore_index = True)

# %% [markdown]
# ## Forecast
#
# Forecasting is another word for predicting time series data.
#
# 1. Last Observed Value: The future will look like the now
# 2. Simple Average: The future will look, on average, like history.
# 3. Moving Average: The future will look, on average, like recent history.
# 4. Holt's Linear Trend
# 5. Previous Cycle
#
#
# ### Last observed value
#
# The simplest method for forecasting is to predict all future values to be the last observed value.
#
# **Make Predictions**
#
# Sales Total

# %%
train['sales_total'][-1:][0]
# Out:
# 178036.63999999998

# %%
# take the last item of sales total and assign to variable
last_sales = train['sales_total'][-1:][0]
last_sales
# Out:
# 178036.63999999998

# %% [markdown]
# Quantity

# %%
# take the last item of quantity and assign to variable
last_quantity = train['quantity'][-1:][0]
last_quantity
# Out:
# 33134

# %%
yhat_df = pd.DataFrame(
    {'sales_total': [last_sales],
     'quantity': [last_quantity]},
    index=validate.index)

yhat_df.head()
# Out:
#             sales_total  quantity
# sale_date
# 2015-07-03    178036.64     33134
# 2015-07-04    178036.64     33134
# 2015-07-05    178036.64     33134
# 2015-07-06    178036.64     33134
# 2015-07-07    178036.64     33134

# %%
yhat_df.describe()
# Out:
#         sales_total  quantity
# count  5.480000e+02     548.0
# mean   1.780366e+05   33134.0
# std    5.243476e-10       0.0
# min    1.780366e+05   33134.0
# 25%    1.780366e+05   33134.0
# 50%    1.780366e+05   33134.0
# 75%    1.780366e+05   33134.0
# max    1.780366e+05   33134.0

# %% [markdown]
# You can see, when peeking into yhat_df, that every predicted value is the same.
#
# **Plot Actual vs. Predicted Values**
#
# Now, let's plot actual and predicted values

# %%
plot_and_eval('sales_total')
# Out:
# sales_total -- RMSE: 42805

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# quantity -- RMSE: 7973
# sales_total -- RMSE: 42805

# %% [markdown]
# **Evaluate**
#
# Evaluate using MSE and RMSE, and add evaluation metrics to `eval_df`

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type = 'last_observed_value', 
                             target_var = col)

eval_df
# Out:
#             model_type   target_var     rmse
# 0  last_observed_value     quantity   7973.0
# 1  last_observed_value  sales_total  42805.0

# %% [markdown]
# ### Simple Average
#
# Take the simple average of historical values in train and use that value to predict future values.
#
# This is a good option for an initial baseline. Every future datapoint (those in 'test') will be assigned the same value.
#
# **Make Predictions**
#
# Dollars: establishing the value of the prediction we will make

# %%
# compute simple average
avg_sales = round(train['sales_total'].mean(), 2)
avg_sales
# Out:
# 127573.19

# %% [markdown]
# Items: establishing the value of the prediction we will make

# %%
avg_quantity = round(train['quantity'].mean(), 2)
avg_quantity
# Out:
# 23728.25

# %% [markdown]
# Apply predictions to our observations

# %%
def make_predictions(sales=None, quantity=None):
    yhat_df = pd.DataFrame({'sales_total': [sales],
                           'quantity': [quantity]},
                          index=validate.index)
    return yhat_df

# %%
yhat_df = make_predictions(avg_sales, avg_quantity)

# %%
yhat_df.head()
# Out:
#             sales_total  quantity
# sale_date
# 2015-07-03    127573.19  23728.25
# 2015-07-04    127573.19  23728.25
# 2015-07-05    127573.19  23728.25
# 2015-07-06    127573.19  23728.25
# 2015-07-07    127573.19  23728.25

# %%
yhat_df.describe()
# Out:
#         sales_total  quantity
# count  5.480000e+02    548.00
# mean   1.275732e+05  23728.25
# std    9.467387e-10      0.00
# min    1.275732e+05  23728.25
# 25%    1.275732e+05  23728.25
# 50%    1.275732e+05  23728.25
# 75%    1.275732e+05  23728.25
# max    1.275732e+05  23728.25

# %% [markdown]
# **Plot Actual vs. Predicted Values**
#
# Now, let's plot and evaluate the performance of our time series model using **Simple Average**

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# quantity -- RMSE: 7360
# sales_total -- RMSE: 39568

# %% [markdown]
# **Evaluate**
#
# Evaluate using MSE and RMSE, and add evaluation metrics to `eval_df`

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type='simple_average', 
                            target_var = col)
eval_df
# Out:
#             model_type   target_var     rmse
# 0  last_observed_value     quantity   7973.0
# 1  last_observed_value  sales_total  42805.0
# 2       simple_average     quantity   7360.0
# 3       simple_average  sales_total  39568.0

# %% [markdown]
# ### Moving Average
#
# In this example, we will use a 30-day moving average to forecast. In other words, the average over the last 30-days will be used as the forecasted value.

# %%
# demonstrate that the mean of the first 30 days 
# is equal to rolling(30) on day 30

print(train['sales_total'].rolling(30).mean())
# Out:
# sale_date
# 2013-01-01              NaN
# 2013-01-02              NaN
# 2013-01-03              NaN
# 2013-01-04              NaN
# 2013-01-05              NaN
#                   ...
# 2015-06-28    170365.098000
# 2015-06-29    168925.788333
# 2015-06-30    167925.392000
# 2015-07-01    168957.912000
# 2015-07-02    169649.376333
# Freq: D, Name: sales_total, Length: 913, dtype: float64

# %% [markdown]
# **Make Predictions**

# %%
period=30
train['sales_total'].rolling(period).mean()[-1]
# Out:
# 169649.37633333335

# %%
period = 30 

# take 30 day rolling average, then take the last element and that will the one that propogates 
# forward as our prediction. 
rolling_sales = round(train['sales_total'].rolling(period).mean()[-1], 2)
rolling_quantity = round(train['quantity'].rolling(period).mean()[-1], 2)
print(rolling_sales, rolling_quantity)
# Out:
# 169649.38 31561.9

# %%
yhat_df = make_predictions(rolling_sales, rolling_quantity)
yhat_df.head()
# Out:
#             sales_total  quantity
# sale_date
# 2015-07-03    169649.38   31561.9
# 2015-07-04    169649.38   31561.9
# 2015-07-05    169649.38   31561.9
# 2015-07-06    169649.38   31561.9
# 2015-07-07    169649.38   31561.9

# %% [markdown]
# **Plot Actual vs. Predicted Values**
#
# Now, let's plot and evaluate the performance of our time series model using **Moving Average**

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# quantity -- RMSE: 7048
# sales_total -- RMSE: 37882

# %% [markdown]
# **Evaluate**
#
# Evaluate using MSE and RMSE, and add evaluation metrics to `eval_df`

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type = '30d_moving_avg', 
                            target_var = col)

eval_df
# Out:
#             model_type   target_var     rmse
# 0  last_observed_value     quantity   7973.0
# 1  last_observed_value  sales_total  42805.0
# 2       simple_average     quantity   7360.0
# 3       simple_average  sales_total  39568.0
# 4       30d_moving_avg     quantity   7048.0
# 5       30d_moving_avg  sales_total  37882.0

# %% [markdown]
# Let's try out several other values for periods:

# %%
periods = [4, 12, 26, 52, 104]

for p in periods: 
    rolling_sales = round(train['sales_total'].rolling(p).mean()[-1], 2)
    rolling_quantity = round(train['quantity'].rolling(p).mean()[-1], 2)
    yhat_df = make_predictions(rolling_sales, rolling_quantity)
    model_type = str(p) + '_day_moving_avg'
    for col in train.columns:
        eval_df = append_eval_df(model_type = model_type,
                                target_var = col)

# %%
eval_df
# Out:
#              model_type   target_var     rmse
# 0   last_observed_value     quantity   7973.0
# 1   last_observed_value  sales_total  42805.0
# 2        simple_average     quantity   7360.0
# 3        simple_average  sales_total  39568.0
# 4        30d_moving_avg     quantity   7048.0
# 5        30d_moving_avg  sales_total  37882.0
# 6      4_day_moving_avg     quantity   6258.0
# 7      4_day_moving_avg  sales_total  33696.0
# 8     12_day_moving_avg     quantity   6929.0
# 9     12_day_moving_avg  sales_total  37297.0
# 10    26_day_moving_avg     quantity   6991.0
# 11    26_day_moving_avg  sales_total  37576.0
# 12    52_day_moving_avg     quantity   6666.0
# 13    52_day_moving_avg  sales_total  35876.0
# 14   104_day_moving_avg     quantity   6130.0
# 15   104_day_moving_avg  sales_total  32959.0

# %% [markdown]
# Which is best so far?

# %%
min_items_rmse = eval_df[eval_df.target_var == 'quantity']['rmse'].min()

# %%
min_items_rmse
# Out:
# 6130.0

# %%
eval_df[eval_df.rmse == min_items_rmse]
# Out:
#             model_type target_var    rmse
# 14  104_day_moving_avg   quantity  6130.0

# %%
min_dollars_rmse = eval_df[eval_df.target_var == 'sales_total']['rmse'].min()

eval_df[eval_df.rmse == min_dollars_rmse]
# Out:
#             model_type   target_var     rmse
# 15  104_day_moving_avg  sales_total  32959.0

# %% [markdown]
# ### Holt's Linear Trend
#
#
# Exponential smoothing applied to both the average and the trend (slope).
#
# - $\alpha$ / smoothing_level: smoothing parameter for mean. Values closer to 1 will have less of a smoothing effect and will give greater weight to recent values.
# - $\beta$ / smoothing_slope: smoothing parameter for the slope. Values closer to 1 will give greater weight to recent slope/values.
#
#
#
# **Seasonal Decomposition**
#
#
# First, let's take a look at the seasonal decomposition for each target.

# %%
import statsmodels.api as sm

# %%
col
# Out:
# 'sales_total'

# %%
print(col, '\n')
sm.tsa.seasonal_decompose(train[col].resample('W').mean()).plot()
plt.show()
# Out:
# sales_total

# %%
for col in train.columns:
    print(col,'\n')
    sm.tsa.seasonal_decompose(train[col].resample('W').mean()).plot()
# Out:
# quantity
#
# sales_total

# %% [markdown]
# #### Basic Holt's Linear Trend
#
# **Make Predictions**
#
# Now, like we would when using sklearn, we will create the Holt object, fit the model, and make predictions.
#
# Holt:
#
# - exponential = True/False (exponential vs. linear growth, additive vs. multiplicative)
# - damped $\phi$ = True/False: with Holt, forecasts will increase or decrease indefinitely into the future.  To avoid this, use the Damped trend method which has a damping parameter 0< ϕ <1.
#
#
# fit:
#
# - smoothing_level ($\alpha$): value between (0,1)
#     - Closer to 0, the level doesn't change with each new observation
#     - Closer to 1, the level reacts strongly with each new observation
# - smoothing_slope ($\beta$): value between (0,1)
#     - Closer to 0, trend is not changing over time
#     - Closer to 1, trend is changing significantly over time
# - optimized: use the auto-optimization that allow statsmodels to automatically find an optimized value for us.

# %%
train.columns
# Out:
# Index(['quantity', 'sales_total'], dtype='object')

# %%
col = 'sales_total' 
# create our Holt's Object
model = Holt(train[col], exponential=False, damped=True)

# %%
# fit the holt's object
model = model.fit(optimized=True)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
yhat_items = model.predict(start = validate.index[0],
                              end = validate.index[-1])

# %%
validate.shape
# Out:
# (548, 2)

# %%
validate.head(1)
# Out:
#             quantity  sales_total
# sale_date
# 2015-07-03     35498    190981.55

# %%
# We have two columns so we need to do them individually
yhat_items
# Out:
# 2015-07-03    171117.753291
# 2015-07-04    171264.819256
# 2015-07-05    171410.399197
# 2015-07-06    171554.508129
# 2015-07-07    171697.160916
#                   ...
# 2016-12-27    185613.674887
# 2016-12-28    185614.267178
# 2016-12-29    185614.853485
# 2016-12-30    185615.433867
# 2016-12-31    185616.008384
# Freq: D, Length: 548, dtype: float64

# %%
# doing this in a loop for each column
for col in train.columns:
    model = Holt(train[col], exponential=False, damped=True)
    model = model.fit(optimized=True)
    yhat_items = model.predict(start = validate.index[0],
                              end = validate.index[-1])
    yhat_df[col] = round(yhat_items, 2)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
yhat_df
# Out:
#             sales_total  quantity
# sale_date
# 2015-07-03    171117.75  31831.17
# 2015-07-04    171264.82  31858.88
# 2015-07-05    171410.40  31886.32
# 2015-07-06    171554.51  31913.48
# 2015-07-07    171697.16  31940.36
# ...                 ...       ...
# 2016-12-27    185613.67  34590.34
# 2016-12-28    185614.27  34590.46
# 2016-12-29    185614.85  34590.57
# 2016-12-30    185615.43  34590.69
# 2016-12-31    185616.01  34590.80
#
# [548 rows x 2 columns]

# %% [markdown]
# To practice the code before putting in a loop, as above...

# %%
col = 'sales_total'
# create the Holt object 
model = Holt(train[col], exponential=False, damped=True)
# fit the model 
model = model.fit(optimized=True)
# make predictions for each date in validate 
yhat_items = model.predict(start = validate.index[0],
                           end = validate.index[-1])
# add predictions to yhat_df
yhat_df[col] = round(yhat_items, 2)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
yhat_df
# Out:
#             sales_total  quantity
# sale_date
# 2015-07-03    171117.75  31831.17
# 2015-07-04    171264.82  31858.88
# 2015-07-05    171410.40  31886.32
# 2015-07-06    171554.51  31913.48
# 2015-07-07    171697.16  31940.36
# ...                 ...       ...
# 2016-12-27    185613.67  34590.34
# 2016-12-28    185614.27  34590.46
# 2016-12-29    185614.85  34590.57
# 2016-12-30    185615.43  34590.69
# 2016-12-31    185616.01  34590.80
#
# [548 rows x 2 columns]

# %%
validate
# Out:
#             quantity  sales_total
# sale_date
# 2015-07-03     35498    190981.55
# 2015-07-04     37776    203696.39
# 2015-07-05     39740    214040.37
# 2015-07-06     26519    142584.15
# 2015-07-07     30916    167146.03
# ...              ...          ...
# 2016-12-27     19341    103657.89
# 2016-12-28     19560    105313.94
# 2016-12-29     21111    113221.85
# 2016-12-30     22296    120033.64
# 2016-12-31     23792    128009.31
#
# [548 rows x 2 columns]

# %%
yhat_items
# Out:
# 2015-07-03    171117.753291
# 2015-07-04    171264.819256
# 2015-07-05    171410.399197
# 2015-07-06    171554.508129
# 2015-07-07    171697.160916
#                   ...
# 2016-12-27    185613.674887
# 2016-12-28    185614.267178
# 2016-12-29    185614.853485
# 2016-12-30    185615.433867
# 2016-12-31    185616.008384
# Freq: D, Length: 548, dtype: float64

# %%
yhat_df
# Out:
#             sales_total  quantity
# sale_date
# 2015-07-03    171117.75  31831.17
# 2015-07-04    171264.82  31858.88
# 2015-07-05    171410.40  31886.32
# 2015-07-06    171554.51  31913.48
# 2015-07-07    171697.16  31940.36
# ...                 ...       ...
# 2016-12-27    185613.67  34590.34
# 2016-12-28    185614.27  34590.46
# 2016-12-29    185614.85  34590.57
# 2016-12-30    185615.43  34590.69
# 2016-12-31    185616.01  34590.80
#
# [548 rows x 2 columns]

# %% [markdown]
# **Plot Actual vs. Predicted Values**

# %%
for col in train.columns:
    plot_and_eval(target_var = col)
# Out:
# quantity -- RMSE: 8692
# sales_total -- RMSE: 46542

# %% [markdown]
# **Evaluate**

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type = 'holts_optimized', 
                            target_var = col)

# %%
eval_df.sort_values(by='rmse')
# Out:
#              model_type   target_var     rmse
# 14   104_day_moving_avg     quantity   6130.0
# 6      4_day_moving_avg     quantity   6258.0
# 12    52_day_moving_avg     quantity   6666.0
# 8     12_day_moving_avg     quantity   6929.0
# 10    26_day_moving_avg     quantity   6991.0
# 4        30d_moving_avg     quantity   7048.0
# 2        simple_average     quantity   7360.0
# 0   last_observed_value     quantity   7973.0
# 16      holts_optimized     quantity   8692.0
# 15   104_day_moving_avg  sales_total  32959.0
# 7      4_day_moving_avg  sales_total  33696.0
# 13    52_day_moving_avg  sales_total  35876.0
# 9     12_day_moving_avg  sales_total  37297.0
# 11    26_day_moving_avg  sales_total  37576.0
# 5        30d_moving_avg  sales_total  37882.0
# 3        simple_average  sales_total  39568.0
# 1   last_observed_value  sales_total  42805.0
# 17      holts_optimized  sales_total  46542.0

# %% [markdown]
# #### Holt's Seasonal Trend

# %%
# Models for quantity
fit1 = ExponentialSmoothing(train.quantity, seasonal_periods=365, trend='add', seasonal='add', use_boxcox=True).fit()
fit2 = ExponentialSmoothing(train.quantity, seasonal_periods=365, trend='add', seasonal='mul', use_boxcox=True).fit()
fit3 = ExponentialSmoothing(train.quantity, seasonal_periods=365, trend='add', seasonal='add', damped=True, use_boxcox=True).fit()
fit4 = ExponentialSmoothing(train.quantity, seasonal_periods=365, trend='add', seasonal='mul', damped=True, use_boxcox=True).fit()

# Models for sales
fit5 = ExponentialSmoothing(train.sales_total, seasonal_periods=365, trend='add', seasonal='add', use_boxcox=True).fit()
fit6 = ExponentialSmoothing(train.sales_total, seasonal_periods=365, trend='add', seasonal='mul', use_boxcox=True).fit()
fit7 = ExponentialSmoothing(train.sales_total, seasonal_periods=365, trend='add', seasonal='add', damped=True, use_boxcox=True).fit()
fit8 = ExponentialSmoothing(train.sales_total, seasonal_periods=365, trend='add', seasonal='mul', damped=True, use_boxcox=True).fit()

# %%
fit1.params
# Out:
# {'smoothing_level': 0.04224441453211016,
#  'smoothing_trend': 0.0003621912879281645,
#  'smoothing_seasonal': 0.17136898746009838,
#  'damping_trend': nan,
#  'initial_level': 569.3059778157933,
#  'initial_trend': 0.08618519116142252,
#  'initial_seasons': array([-1.24081989e+02, -9.94143397e+01, -8.70761819e+01, -6.34563859e+01,
#         -5.29108557e+01, -1.58223461e+02, -1.25339612e+02, -1.22616702e+02,
#         -1.00978278e+02, -8.44485994e+01, -6.82410796e+01, -5.66621766e+01,
#         -1.59312724e+02, -1.24784258e+02, -1.25037643e+02, -1.01655752e+02,
#         -8.64439512e+01, -6.87454865e+01, -5.59515600e+01, -1.58458769e+02,
#         -1.30061508e+02, -1.23634552e+02, -1.06655299e+02, -8.17686174e+01,
#         -6.61392097e+01, -5.47022085e+01, -1.60192797e+02, -1.26830251e+02,
#         -1.25830381e+02, -1.05397545e+02, -8.53439660e+01, -3.63217484e+01,
#         -1.74687635e+01, -1.31447140e+02, -9.73036883e+01, -9.06823894e+01,
#         -7.33843504e+01, -5.78156336e+01, -3.23947105e+01, -2.05840237e+01,
#         -1.36263680e+02, -9.86935758e+01, -9.73223888e+01, -7.84853075e+01,
#         -5.54426005e+01, -3.82935411e+01, -2.35753123e+01, -1.37309310e+02,
#         -1.00533012e+02, -9.52757466e+01, -7.66642361e+01, -5.81998620e+01,
#         -3.91821321e+01, -2.29880828e+01, -1.33129920e+02, -1.01137941e+02,
#         -9.44720364e+01, -7.99287073e+01, -5.78740794e+01,  2.35780932e+01,
#          4.11802623e+01, -8.31505257e+01, -4.11631028e+01, -3.92713436e+01,
#         -2.04067270e+01,  5.51447745e+00,  2.28556784e+01,  4.06215294e+01,
#         -8.57527807e+01, -4.60675075e+01, -4.47190006e+01, -2.03564533e+01,
#          3.92569004e+00,  2.73764804e+01,  3.95629849e+01, -8.65226132e+01,
#         -4.72885538e+01, -4.47921145e+01, -2.49862239e+01, -1.10336788e-01,
#          2.35588023e+01,  3.88407287e+01, -8.72799906e+01, -5.13082734e+01,
#         -4.33508803e+01, -2.30322351e+01,  4.76928994e-01,  2.24619214e+01,
#          3.77429536e+01, -8.67048233e+01,  5.69640213e-01,  6.48749960e+00,
#          3.57752542e+01,  5.42229878e+01,  8.14374024e+01,  1.02080637e+02,
#         -3.85245259e+01,  5.30776049e+00,  7.35346807e+00,  3.17847631e+01,
#          5.40759066e+01,  7.83475391e+01,  9.70475524e+01, -3.88388192e+01,
#          4.41714792e+00,  6.69586514e+00,  3.43966446e+01,  5.23538990e+01,
#          7.94794688e+01,  9.58620009e+01, -4.17056147e+01,  5.60528224e+00,
#          5.08887492e+00,  2.74294259e+01,  5.38928400e+01,  7.73684803e+01,
#          9.66086419e+01, -4.27844571e+01,  2.43331599e+00,  6.07427573e+00,
#          5.68779125e+01,  8.38678007e+01,  1.05913725e+02,  1.23359302e+02,
#         -1.94334964e+01,  3.00484343e+01,  2.66474133e+01,  5.10738875e+01,
#          7.79801854e+01,  1.05265132e+02,  1.20294865e+02, -1.61027369e+01,
#          2.75328245e+01,  3.05391936e+01,  5.44835537e+01,  7.73593081e+01,
#          1.08582267e+02,  1.21353689e+02, -2.21517809e+01,  2.34917690e+01,
#          2.84370993e+01,  5.12855211e+01,  7.32039793e+01,  1.03652327e+02,
#          1.18633807e+02, -2.03777372e+01,  2.45693747e+01,  2.64218717e+01,
#          5.15764748e+01,  7.84797568e+01,  1.01516220e+02,  1.47507718e+02,
#          5.92066555e-01,  4.27854910e+01,  5.39352467e+01,  7.59533231e+01,
#          1.00160716e+02,  1.24021625e+02,  1.45504910e+02, -1.84018595e-01,
#          4.80790305e+01,  4.94800137e+01,  7.36346205e+01,  1.02186948e+02,
#          1.31968027e+02,  1.52435213e+02,  5.22280817e-01,  4.60711495e+01,
#          4.99479185e+01,  7.63366684e+01,  1.02873851e+02,  1.33352896e+02,
#          1.42393695e+02,  1.78836164e+00,  3.96296745e+01,  4.89454270e+01,
#          7.88285920e+01,  1.02012086e+02,  1.28165341e+02,  1.45511865e+02,
#         -5.38052241e+00,  6.62528892e+01,  6.93162890e+01,  6.76298666e+01,
#          9.23422737e+01,  1.17266995e+02,  1.41233490e+02,  1.55423279e+02,
#          1.42667099e+01,  6.55269814e+01,  6.44599320e+01,  9.61149724e+01,
#          1.19514429e+02,  1.44868733e+02,  1.56439416e+02,  9.53397328e+00,
#          6.53323648e+01,  6.27738303e+01,  9.08415728e+01,  1.19747518e+02,
#          1.40985085e+02,  1.56398747e+02,  9.12559323e+00,  6.07195332e+01,
#          6.70538469e+01,  9.08427739e+01,  1.17208661e+02,  1.45370075e+02,
#          1.56237137e+02,  7.41676354e+00,  6.28241872e+01,  6.05793525e+01,
#          3.68773205e+01,  6.77811050e+01,  9.16857592e+01,  1.03196259e+02,
#         -3.14701602e+01,  1.51567405e+01,  1.20400003e+01,  4.05542165e+01,
#          6.27405967e+01,  8.59856075e+01,  1.01812618e+02, -3.32854346e+01,
#          1.27771735e+01,  1.53029248e+01,  3.99227180e+01,  6.70244109e+01,
#          9.07613621e+01,  1.00035560e+02, -3.76974271e+01,  1.51745721e+01,
#          1.45997009e+01,  4.11453286e+01,  5.93146558e+01,  8.81187376e+01,
#          9.66981411e+01, -3.66987732e+01,  1.43257501e+01,  1.50614571e+01,
#          3.65471756e+01,  6.49338673e+01,  8.35365348e+01,  7.27172169e+01,
#         -5.25903578e+01, -9.24163836e+00, -1.21017226e+01,  1.27664462e+01,
#          3.73941202e+01,  5.95828702e+01,  7.16362000e+01, -6.04132255e+01,
#         -8.36663521e+00, -1.17972422e+01,  1.19358249e+01,  3.52920209e+01,
#          5.87105342e+01,  6.99204606e+01, -5.66372893e+01, -1.89742468e+01,
#         -1.02389875e+01,  1.54947060e+01,  3.35488973e+01,  5.88922712e+01,
#          7.14407185e+01, -6.02107642e+01, -1.46302098e+01, -1.08194500e+01,
#          7.67028186e+00,  3.35456930e+01,  5.00304554e+01,  6.94967854e+01,
#         -6.19750618e+01, -4.08285531e+01, -3.62598835e+01, -1.71924286e+01,
#          5.19190782e+00,  2.61719532e+01,  3.93161525e+01, -8.33996994e+01,
#         -4.18777035e+01, -4.26777588e+01, -1.19359348e+01,  2.75906032e+00,
#          2.45062762e+01,  4.00457730e+01, -8.80251041e+01, -4.32428849e+01,
#         -4.15831257e+01, -1.88273468e+01,  1.58012077e+00,  2.70630035e+01,
#          3.58017330e+01, -8.94078840e+01, -4.27321971e+01, -4.25897505e+01,
#         -1.89230343e+01,  2.80582376e+00,  2.12847601e+01,  3.53515104e+01,
#         -9.01752619e+01, -4.37076321e+01, -4.03314751e+01, -2.06168247e+01,
#          2.84317702e+01,  4.74124511e+01,  6.34025732e+01, -6.66757023e+01,
#         -1.98808089e+01, -2.16787849e+01,  1.13207250e+00,  3.00746371e+01,
#          5.05086032e+01,  6.11869275e+01, -6.49257535e+01, -2.07560700e+01,
#         -2.08253295e+01,  6.69815464e-01,  2.63332830e+01,  4.74200570e+01,
#          6.09931990e+01, -6.80808188e+01, -2.13798137e+01, -1.83557195e+01,
#         -3.19058599e-01,  2.81851490e+01,  4.81216254e+01,  6.12561202e+01,
#         -6.87211895e+01, -2.41609799e+01, -2.08714247e+01, -9.24516042e-01,
#          2.50068978e+01,  4.54485907e+01, -6.00863640e+01, -1.62497586e+02,
#         -1.25776845e+02, -1.23891485e+02, -1.06998934e+02, -8.62991621e+01,
#         -6.69247555e+01, -6.20193713e+01, -1.66896160e+02, -1.27586036e+02,
#         -1.25663142e+02, -1.06431460e+02, -8.95107152e+01, -7.18230126e+01,
#         -5.62012638e+01, -1.65289737e+02, -1.31720016e+02, -1.28792337e+02,
#         -1.10444416e+02, -9.26157438e+01, -7.00487453e+01, -5.76441008e+01,
#         -1.67194990e+02, -1.30427706e+02, -1.25620521e+02, -1.10130412e+02,
#         -9.53798607e+01, -7.22182200e+01, -6.72777777e+01, -1.69716841e+02,
#         -1.32849444e+02]),
#  'use_boxcox': True,
#  'lamda': 0.5836182072713239,
#  'remove_bias': False}

# %%
results_quantity=pd.DataFrame(index=[r"$\alpha$",r"$\beta$",r"$\phi$",r"$\gamma$",r"$l_0$","$b_0$","SSE"])
params = ['smoothing_level', 'smoothing_trend', 'damping_trend', 'smoothing_seasonal', 'initial_level', 'initial_trend']
results_quantity["Additive(fit1-Quantity)"] = [fit1.params[p] for p in params] + [fit1.sse]
results_quantity["Multiplicative(fit2-Quantity)"] = [fit2.params[p] for p in params] + [fit2.sse]
results_quantity["Additive_Dampened(fit3-Quantity)"]   = [fit3.params[p] for p in params] + [fit3.sse]
results_quantity["Multiplicative_Dampened(fit4-Quantity)"] = [fit4.params[p] for p in params] + [fit4.sse]

# %%
results_quantity
# Out:
#           Additive(fit1-Quantity)  Multiplicative(fit2-Quantity)  \
# $\alpha$             4.224441e-02                   4.036653e-02
# $\beta$              3.621913e-04                   1.614651e-02
# $\phi$                        NaN                            NaN
# $\gamma$             1.713690e-01                   1.371082e-01
# $l_0$                5.693060e+02                   5.772077e+02
# $b_0$                8.618519e-02                   6.293996e-02
# SSE                  8.417028e+09                   5.905274e+09
#
#           Additive_Dampened(fit3-Quantity)  \
# $\alpha$                      4.074005e-02
# $\beta$                       1.649867e-02
# $\phi$                        9.874932e-01
# $\gamma$                      1.698211e-01
# $l_0$                         5.606512e+02
# $b_0$                         2.543991e+00
# SSE                           7.321321e+09
#
#           Multiplicative_Dampened(fit4-Quantity)
# $\alpha$                            4.036536e-02
# $\beta$                             8.073035e-03
# $\phi$                              9.899988e-01
# $\gamma$                            1.371174e-01
# $l_0$                               5.772039e+02
# $b_0$                              -7.198833e-01
# SSE                                 5.825951e+09

# %%
# Which test performed the best?
results_quantity.T[results_quantity.T['SSE'] == results_quantity.T.SSE.min()].index[0]
# Out:
# 'Multiplicative_Dampened(fit4-Quantity)'

# %%
ax = validate.quantity.plot(figsize=(18,6), color='orange', title="Quantity (Forecasts from Holt-Winters' Seasonal Method)")
ax.set_ylabel("")
ax.set_xlabel("Year")
train.quantity.plot()

fit4.forecast(validate.shape[0]).rename('Holt-Winters (damp-mul-seasonal(fit4))').plot(ax=ax, style='--', color='green', legend=True)

plt.show()

# %%
results_sales=pd.DataFrame(index=[r"$\alpha$",r"$\beta$",r"$\phi$",r"$\gamma$",r"$l_0$","$b_0$","SSE"])
params = ['smoothing_level', 'smoothing_trend', 'damping_trend', 'smoothing_seasonal', 'initial_level', 'initial_trend']
results_sales["Additive(fit5-Sales)"] = [fit5.params[p] for p in params] + [fit5.sse]
results_sales["Multiplicative(fit6-Sales)"] = [fit6.params[p] for p in params] + [fit6.sse]
results_sales["Additive_Dampened(fit7-Sales)"]   = [fit7.params[p] for p in params] + [fit7.sse]
results_sales["Multiplicative_Dampened(fit8-Sales)"] = [fit8.params[p] for p in params] + [fit8.sse]

# %%
results_sales
# Out:
#           Additive(fit5-Sales)  Multiplicative(fit6-Sales)  \
# $\alpha$          1.365589e-01                4.035716e-02
# $\beta$           1.399625e-02                1.614269e-02
# $\phi$                     NaN                         NaN
# $\gamma$          2.252603e-01                1.371007e-01
# $l_0$             1.441424e+03                1.532274e+03
# $b_0$             4.024877e-01                4.544883e-01
# SSE               2.270602e+11                1.803238e+11
#
#           Additive_Dampened(fit7-Sales)  Multiplicative_Dampened(fit8-Sales)
# $\alpha$                   4.074014e-02                         4.035940e-02
# $\beta$                    1.629223e-02                         8.071917e-03
# $\phi$                     9.899806e-01                         9.899996e-01
# $\gamma$                   1.715953e-01                         1.370938e-01
# $l_0$                      1.531792e+03                         1.532174e+03
# $b_0$                     -4.333571e-01                        -1.085002e+00
# SSE                        2.623347e+11                         1.682501e+11

# %%
# Which test performed the best?
results_sales.T[results_sales.T['SSE'] == results_sales.T.SSE.min()].index[0]
# Out:
# 'Multiplicative_Dampened(fit8-Sales)'

# %%
ax = validate.sales_total.plot(figsize=(18,6), color='orange', title="Sales Total (Forecasts from Holt-Winters' Seasonal Method)")
ax.set_ylabel("")
ax.set_xlabel("Year")
train.sales_total.plot()

fit8.forecast(validate.shape[0]).rename('Holt-Winters (damp-mul-seasonal(fit8))').plot(ax=ax, style='--', color='black', legend=True, alpha=0.4)

plt.show()

# %%
yhat_df.head()
# Out:
#             sales_total  quantity
# sale_date
# 2015-07-03    171117.75  31831.17
# 2015-07-04    171264.82  31858.88
# 2015-07-05    171410.40  31886.32
# 2015-07-06    171554.51  31913.48
# 2015-07-07    171697.16  31940.36

# %%
yhat_df = fit8.forecast(validate.shape[0]).rename('sales_total').to_frame()
yhat_df['quantity'] = fit4.forecast(validate.shape[0]).rename('quantity').to_frame()
yhat_df
# Out:
#               sales_total      quantity
# 2015-07-03  172742.808670  31935.502810
# 2015-07-04  183823.659773  34108.980048
# 2015-07-05  195048.974471  36246.181090
# 2015-07-06  207606.107881  38445.126254
# 2015-07-07  172842.008643  32006.070194
# ...                   ...           ...
# 2016-12-27  112031.946109  19997.687697
# 2016-12-28   90648.483032  16268.376619
# 2016-12-29   83812.199562  14929.168475
# 2016-12-30   87684.831117  15578.368739
# 2016-12-31   83106.144974  14852.302491
#
# [548 rows x 2 columns]

# %%
evaluate('sales_total')
# Out:
# 28725.0

# %%
evaluate('quantity')
# Out:
# 5602.0

# %%
eval_df = append_eval_df('seasonal_holts_dampened_add(fit8)', 'sales_total')
eval_df = append_eval_df('seasonal_holts_dampened_mult(fit4)', 'quantity')
eval_df.sort_values(by='rmse')
# Out:
#                             model_type   target_var     rmse
# 19  seasonal_holts_dampened_mult(fit4)     quantity   5602.0
# 14                  104_day_moving_avg     quantity   6130.0
# 6                     4_day_moving_avg     quantity   6258.0
# 12                   52_day_moving_avg     quantity   6666.0
# 8                    12_day_moving_avg     quantity   6929.0
# 10                   26_day_moving_avg     quantity   6991.0
# 4                       30d_moving_avg     quantity   7048.0
# 2                       simple_average     quantity   7360.0
# 0                  last_observed_value     quantity   7973.0
# 16                     holts_optimized     quantity   8692.0
# 18   seasonal_holts_dampened_add(fit8)  sales_total  28725.0
# 15                  104_day_moving_avg  sales_total  32959.0
# 7                     4_day_moving_avg  sales_total  33696.0
# 13                   52_day_moving_avg  sales_total  35876.0
# 9                    12_day_moving_avg  sales_total  37297.0
# 11                   26_day_moving_avg  sales_total  37576.0
# 5                       30d_moving_avg  sales_total  37882.0
# 3                       simple_average  sales_total  39568.0
# 1                  last_observed_value  sales_total  42805.0
# 17                     holts_optimized  sales_total  46542.0

# %% [markdown]
# ### Predict Based on Previous Cycle

# %% [markdown]
# Take all the 2016 data points, compute the daily delta, year-over-year, average that delta over all the days, and adding that average to the previous year's value on a day will give you the forecast for that day.
#
# If a primary cycle is weekly, then you may want to do this on a week-over-week cadence.
#
# In the below example:
# 1. Compute the 365 average year over year differences from 2013 through 2015
# 2. Add that average delta to the values during 2015.
# 3. Set the index in your yhat dataframe to represent the dates those predictions are make for.
#
# Let's get started....
#
# **Re-split data**

# %%
train = df_resampled[:'2015']
validate = df_resampled['2016']
test = df_resampled['2017']

print(train.shape)
print(validate.shape)
print(test.shape)

train.head()
train.tail()
# Out:
# (1095, 2)
# (366, 2)
# (365, 2)
#             quantity  sales_total
# sale_date
# 2015-12-27     23268    125125.86
# 2015-12-28     15569     84297.45
# 2015-12-29     18403     98602.75
# 2015-12-30     18191     97773.10
# 2015-12-31     19377    103969.42

# %% [markdown]
# **Make Predictions**

# %%
train.diff(365)
# Out:
#             quantity  sales_total
# sale_date
# 2013-01-01       NaN          NaN
# 2013-01-02       NaN          NaN
# 2013-01-03       NaN          NaN
# 2013-01-04       NaN          NaN
# 2013-01-05       NaN          NaN
# ...              ...          ...
# 2015-12-27    1951.0     10605.96
# 2015-12-28   -6963.0    -36765.99
# 2015-12-29    3515.0     18886.81
# 2015-12-30     784.0      4158.67
# 2015-12-31    2139.0     10683.57
#
# [1095 rows x 2 columns]

# %%
# finding the year-over-year difference for each day from 2013 to 2015
# taking the mean, and then adding that value to the daily 2015 values. 

# find yoy diff. from 2013-2014 and 2014-2015, take the mean, and add to each value in 2015. 
yhat_df = train['2015'] + train.diff(365).mean()
yhat_df
# Out:
#                 quantity    sales_total
# sale_date
# 2015-01-01  19411.813699  104337.620493
# 2015-01-02  20904.813699  112870.770493
# 2015-01-03  21983.813699  118245.300493
# 2015-01-04  23286.813699  125496.760493
# 2015-01-05  16420.813699   88551.940493
# ...                  ...            ...
# 2015-12-27  25453.813699  136877.110493
# 2015-12-28  17754.813699   96048.700493
# 2015-12-29  20588.813699  110354.000493
# 2015-12-30  20376.813699  109524.350493
# 2015-12-31  21562.813699  115720.670493
#
# [365 rows x 2 columns]

# %%
train.diff(365).mean()
# Out:
# quantity        2185.813699
# sales_total    11751.250493
# dtype: float64

# %% [markdown]
# Back to predictions

# %%
train.loc['2015'].head()
# Out:
#             quantity  sales_total
# sale_date
# 2015-01-01     17226     92586.37
# 2015-01-02     18719    101119.52
# 2015-01-03     19798    106494.05
# 2015-01-04     21101    113745.51
# 2015-01-05     14235     76800.69

# %%
yhat_df.head()
# Out:
#                 quantity    sales_total
# sale_date
# 2015-01-01  19411.813699  104337.620493
# 2015-01-02  20904.813699  112870.770493
# 2015-01-03  21983.813699  118245.300493
# 2015-01-04  23286.813699  125496.760493
# 2015-01-05  16420.813699   88551.940493

# %%
yhat_df.head(1)
# Out:
#                 quantity    sales_total
# sale_date
# 2015-01-01  19411.813699  104337.620493

# %%
validate.head(1)
# Out:
#             quantity  sales_total
# sale_date
# 2016-01-01     20158    107875.26

# %%
# let's peek into the prediction we will make for 1/1/2016
# by comparing the predicted value 
# (2015 value + year-over-year average difference)
# to the actual 1/1/2016 value
pd.concat([yhat_df.head(1), validate.head(1)])
# Out:
#                 quantity    sales_total
# sale_date
# 2015-01-01  19411.813699  104337.620493
# 2016-01-01  20158.000000  107875.260000

# %%
# set yhat_df to index of validate
yhat_df.index = validate.index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [119], in <cell line: 2>()
#       1 # set yhat_df to index of validate
# ----> 2 yhat_df.index = validate.index
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 365 elements, new values have 366 elements

# %%
yhat_df.shape
# Out:
# (365, 2)

# %%
validate.shape # A leap year!
# Out:
# (366, 2)

# %%
validate = validate[validate.index != '2016-02-29']

# %%
yhat_df
# Out:
#                 quantity    sales_total
# sale_date
# 2015-01-01  19411.813699  104337.620493
# 2015-01-02  20904.813699  112870.770493
# 2015-01-03  21983.813699  118245.300493
# 2015-01-04  23286.813699  125496.760493
# 2015-01-05  16420.813699   88551.940493
# ...                  ...            ...
# 2015-12-27  25453.813699  136877.110493
# 2015-12-28  17754.813699   96048.700493
# 2015-12-29  20588.813699  110354.000493
# 2015-12-30  20376.813699  109524.350493
# 2015-12-31  21562.813699  115720.670493
#
# [365 rows x 2 columns]

# %%
# set yhat_df to index of validate
# yhat_df: 2015 values + the mean year over year difference for the entire training dataset
yhat_df.index = validate.index

# %%
yhat_df.head()
# Out:
#                 quantity    sales_total
# sale_date
# 2016-01-01  19411.813699  104337.620493
# 2016-01-02  20904.813699  112870.770493
# 2016-01-03  21983.813699  118245.300493
# 2016-01-04  23286.813699  125496.760493
# 2016-01-05  16420.813699   88551.940493

# %%
yhat_df.describe()
# Out:
#            quantity    sales_total
# count    365.000000     365.000000
# mean   28314.271233  152236.991370
# std     5816.407123   31264.033981
# min    16153.813699   87009.270493
# 25%    23977.813699  128679.520493
# 50%    27913.813699  150024.320493
# 75%    33022.813699  177535.990493
# max    41979.813699  225791.620493

# %%
yhat_df.shape
# Out:
# (365, 2)

# %% [markdown]
# **Plot and Evaluate**

# %%
for col in train.columns:
    plot_and_eval(target_var = col)
    eval_df = append_eval_df(model_type = "previous_year", 
                            target_var = col)
# Out:
# quantity -- RMSE: 5223
# sales_total -- RMSE: 28087

# %% [markdown]
# ## Conclusion
#
# Which model did the best?

# %%
eval_df.sort_values(by='rmse')
# Out:
#                             model_type   target_var     rmse
# 20                       previous_year     quantity   5223.0
# 19  seasonal_holts_dampened_mult(fit4)     quantity   5602.0
# 14                  104_day_moving_avg     quantity   6130.0
# 6                     4_day_moving_avg     quantity   6258.0
# 12                   52_day_moving_avg     quantity   6666.0
# 8                    12_day_moving_avg     quantity   6929.0
# 10                   26_day_moving_avg     quantity   6991.0
# 4                       30d_moving_avg     quantity   7048.0
# 2                       simple_average     quantity   7360.0
# 0                  last_observed_value     quantity   7973.0
# 16                     holts_optimized     quantity   8692.0
# 21                       previous_year  sales_total  28087.0
# 18   seasonal_holts_dampened_add(fit8)  sales_total  28725.0
# 15                  104_day_moving_avg  sales_total  32959.0
# 7                     4_day_moving_avg  sales_total  33696.0
# 13                   52_day_moving_avg  sales_total  35876.0
# 9                    12_day_moving_avg  sales_total  37297.0
# 11                   26_day_moving_avg  sales_total  37576.0
# 5                       30d_moving_avg  sales_total  37882.0
# 3                       simple_average  sales_total  39568.0
# 1                  last_observed_value  sales_total  42805.0
# 17                     holts_optimized  sales_total  46542.0

# %%
sales_total_min_rmse = eval_df.groupby('target_var')['rmse'].min()[0]

quantity_min_rmse = eval_df.groupby('target_var')['rmse'].min()[1]

# find which model that is
eval_df[((eval_df.rmse == sales_total_min_rmse) | 
         (eval_df.rmse == quantity_min_rmse))]
# Out:
#        model_type   target_var     rmse
# 20  previous_year     quantity   5223.0
# 21  previous_year  sales_total  28087.0

# %% [markdown]
# ### Let's See how our Previous Cycle Model Performs on Test
#
# We will be using train + validate to predict test.

# %%
yhat_df = validate + train.diff(365).mean()
yhat_df.index = test.index

# %%
yhat_df
# Out:
#                 quantity    sales_total
# sale_date
# 2017-01-01  22343.813699  119626.510493
# 2017-01-02  23465.813699  126081.680493
# 2017-01-03  25096.813699  134896.160493
# 2017-01-04  17384.813699   92625.220493
# 2017-01-05  19991.813699  107181.150493
# ...                  ...            ...
# 2017-12-27  21526.813699  115409.140493
# 2017-12-28  21745.813699  117065.190493
# 2017-12-29  23296.813699  124973.100493
# 2017-12-30  24481.813699  131784.890493
# 2017-12-31  25977.813699  139760.560493
#
# [365 rows x 2 columns]

# %%
def final_plot(target_var):
    plt.figure(figsize=(12,4))
    plt.plot(train[target_var], label='train')
    plt.plot(validate[target_var], label='validate')
    plt.plot(test[target_var], label='test')
    plt.plot(yhat_df[target_var], alpha=.5)
    plt.title(target_var)
    plt.show()

# %%
rmse_sales_total = sqrt(mean_squared_error(test['sales_total'], 
                                       yhat_df['sales_total']))

rmse_quantity = sqrt(mean_squared_error(test['quantity'], 
                                       yhat_df['quantity']))

# %%
print('rmse-sales total: ', rmse_sales_total)
print('rmse-quantity: ', rmse_quantity)
# Out:
# rmse-sales total:  27114.786014988113
# rmse-quantity:  5040.989142541608

# %%
for col in train.columns:
    final_plot(col)

# %%
# to predict 2018

yhat_df = test + train.diff(365).mean()

yhat_df.index = test.index + pd.Timedelta('1Y')

# %%
yhat_df.head()
# Out:
#                          quantity    sales_total
# sale_date
# 2018-01-01 05:49:12  25894.813699  139013.960493
# 2018-01-02 05:49:12  17957.813699   97081.230493
# 2018-01-03 05:49:12  20835.813699  112140.900493
# 2018-01-04 05:49:12  20695.813699  111205.840493
# 2018-01-05 05:49:12  22080.813699  119365.050493

# %%
def final_plot(target_var):
    plt.figure(figsize=(12,4))
    plt.plot(train[target_var], label='train')
    plt.plot(validate[target_var], label='validate')
    plt.plot(test[target_var], label='test')
    plt.plot(yhat_df[target_var], alpha=.5, label='forecast')
    plt.title(target_var)
    plt.legend()
    plt.show()

# %%
for col in train.columns:
    final_plot(col)

# %% [markdown]
# ## Exercises
#
# The end result of this exercise should be a Jupyter notebook named `model`.
#
# Using [saas.csv](https://ds.codeup.com/saas.csv) or log data from API usage or store_item_sales
#
# 1. Split data (train/test) and resample by any period, except daily, and aggregate using the sum.
# 2. Forecast, plot and evaluate using each of the 4 parametric based methods we discussed:
#     - Simple Average
#     - Moving Average
#     - Holt's Linear Trend Model
#     - Based on previous year/month/etc., this is up to you.
#
# Optional: Using store item demand
#
# 1. Predict 2018 total **monthly** sales for a single store and/or item by creating a model using prophet.
# 2. Return a dataframe with the month, store_id, y-hat, and the confidence intervals (y-hat lower, y-hat upper).
# 3. Plot the 2018 monthly sales predictions.
